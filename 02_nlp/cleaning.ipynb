# %%
import os
import re
import sys

import MeCab

# %%
nm = MeCab.Tagger('-Owakati')

# txtファイルを全部読み込んで分かち書きやクリーニングをしていく
files = [f for f in os.listdir('./dataset/raw_datas') if f.split('.')[1] == 'txt']
authors = {'dazai': [], 'mori': [], 'akutagawa': []}
cleaned_data = []

# %%
def clean(raw_text):
    """
    ルビや入力者注を削除して一文毎に分割,分かち書き
    """
    text = raw_text.replace('\n', '').replace('\u3000', '')
    text = re.sub('[［《]', '／', text)
    text = re.sub('[］》]', '＼', text)
    text = re.sub('／[^＼]*?＼', '', text)
    text = text.replace('。', '。\n')
    text = text.replace('「', '')
    text = text.replace('」', '\n').split('\n')

    return [nm.parse(t).split(' ') for t in text if t]

for f in files:
        name = f.split('.')[0]
        print(name)
        with open('./dataset/raw_datas/'+str(f), 'r') as f:
            clean_text = clean(f.read())
            authors[name] = clean_text
            cleaned_data += clean_text
# Out:
# akutagawa
# mori
# dazai

# %%
def make_stopdic(lines):
    """
    空白区切りの文の集まりのテキストのリストからストップワードの辞書を作成する。
    """
    calc_words = {}
    for line in lines:
        for word in line:
            if word in calc_words:
                calc_words[str(word)] += 1
            else:
                calc_words[str(word)] = 1
    sorted_stop = sorted(calc_words.items(), key=lambda x:x[1], reverse=True)
    print("sorted_stop:"+str(len(sorted_stop)))
    freq_num = int(len(sorted_stop)*0.03)
    n = 0
    stop_words = []
    print("freq_num:"+str(freq_num))
    for data in sorted_stop:
        stop_words.append(str(data[0]))
        #print('High frequency word: ',str(data[0]), str(data[1]))
        n += 1
        if n > freq_num:
            break
    # 作成したストップワードの辞書の保存
    with open('./origin_stopwords.txt', 'w') as f:
        f.write('\n'.join(stop_words))

make_stopdic(cleaned_data)
print("cleaned_data:"+str(len(cleaned_data)))
# Out:
# sorted_stop:13928
# freq_num:417
# cleaned_data:8876

# %%
# ストップワードリストの作成
stop_data = {}
for f in files:
    with open('./dataset/raw_datas/'+str(f)) as f1:
        print(f)
        nm = MeCab.Tagger('-Owakati')
        text = nm.parse(f1.read()).split(' ')
        for word in text:
            if word in stop_data:
                stop_data[str(word)] += 1
            else:
                stop_data[str(word)] = 1
# Out:
# akutagawa.txt
# mori.txt
# dazai.txt

# %%
sorted_stop = sorted(stop_data.items(), key=lambda x:x[1], reverse=True)

print(len(sorted_stop))

freq_num = int(len(sorted_stop)*0.03)
n = 0
stop_words = []
print(freq_num)
for data in sorted_stop:
    stop_words.append(str(data[0]))
    print('High frequency word: ',str(data[0]), str(data[1]))
    n+= 1
    if n > freq_num:
        break

# 作成したストップワードの辞書の保存
with open('./origin_stopwords.txt', 'w') as f:
    f.write('\n'.join(stop_words))
# Out:
# 14900
# 447
# High frequency word:  、 13365
# High frequency word:  の 8869
# High frequency word:  。 8102
# High frequency word:  に 6747
# High frequency word:  は 6410
# High frequency word:  て 5906
# High frequency word:  を 5388
# High frequency word:  た 5329
# High frequency word:  《 4561
# High frequency word:  》 4556
# High frequency word:  が 3447
# High frequency word:  と 3082
# High frequency word:  で 2866
# High frequency word:  し 2176
# High frequency word:  も 2105
# High frequency word:  　 1802
# High frequency word:  」 1614
# High frequency word:  「 1575
# High frequency word:  ない 1194
# High frequency word:  な 1170
# High frequency word:  い 1092
# High frequency word:  だ 1076
# High frequency word:  か 1067
# High frequency word:  ある 938
# High frequency word:  から 894
# High frequency word:  へ 842
# High frequency word:  う 832
# High frequency word:  まし 727
# High frequency word:  いる 712
# High frequency word:  その 693
# High frequency word:  ます 663
# High frequency word:  人 653
# High frequency word:  こと 642
# High frequency word:  ん 608
# High frequency word:  れ 556
# High frequency word:  それ 543
# High frequency word:  私 542
# High frequency word:  もの 530
# High frequency word:  よう 526
# High frequency word:  云 513
# High frequency word:  さ 505
# High frequency word:  ば 505
# High frequency word:  一 482
# High frequency word:  です 467
# High frequency word:  この 448
# High frequency word:  お 434
# High frequency word:  ぬ 430
# High frequency word:  する 420
# High frequency word:  二 409
# High frequency word:  ふ 398
# High frequency word:  事 397
# High frequency word:  ず 352
# High frequency word:  つて 351
# High frequency word:  来 341
# High frequency word:  何 334
# High frequency word:  つ 331
# High frequency word:  あり 327
# High frequency word:  や 317
# High frequency word:  よ 308
# High frequency word:  中 305
# High frequency word:  ながら 305
# High frequency word:  なっ 299
# High frequency word:  せ 297
# High frequency word:  男 293
# High frequency word:  ね 289
# High frequency word:  見 285
# High frequency word:  そう 279
# High frequency word:  女 275
# High frequency word:  御 274
# High frequency word:  三 273
# High frequency word:  十 273
# High frequency word:  時 265
# High frequency word:  なら 263
# High frequency word:  あっ 260
# High frequency word:  なり 254
# High frequency word:  ？ 254
# High frequency word:  ませ 252
# High frequency word:  まで 249
# High frequency word:  あの 246
# High frequency word:  顔 246
# High frequency word:  彼 240
# High frequency word:  やう 240
# High frequency word:  これ 240
# High frequency word:  五 235
# High frequency word:  ｜ 234
# High frequency word:  ひ 233
# High frequency word:  日 233
# High frequency word:  なる 230
# High frequency word:  でも 223
# High frequency word:  もう 220
# High frequency word:  という 218
# High frequency word:  ゐる 212
# High frequency word:  出 212
# High frequency word:  さん 208
# High frequency word:  言っ 198
# High frequency word:  き 197
# High frequency word:  だけ 193
# High frequency word:  たち 193
# High frequency word:  ござい 191
# High frequency word:  上 183
# High frequency word:  ゐ 181
# High frequency word:  なく 179
# High frequency word:  られ 178
# High frequency word:  しかし 175
# High frequency word:  また 173
# High frequency word:  —— 167
# High frequency word:  あなた 166
# High frequency word:  假名 165
# High frequency word:  前 162
# High frequency word:  る 162
# High frequency word:  たら 160
# High frequency word:  いい 158
# High frequency word:  ばかり 156
# High frequency word:  家 156
# High frequency word:  たり 155
# High frequency word:  声 154
# High frequency word:  いや 151
# High frequency word:  自分 151
# High frequency word:  など 146
# High frequency word:  手 145
# High frequency word:  思っ 145
# High frequency word:  おれ 144
# High frequency word:  あ 143
# High frequency word:  夫 143
# High frequency word:  遣 143
# High frequency word:  … 142
# High frequency word:  ひと 142
# High frequency word:  どう 141
# High frequency word:  じゃ 140
# High frequency word:  わ 139
# High frequency word:  より 137
# High frequency word:  り 137
# High frequency word:  なかっ 137
# High frequency word:  み 136
# High frequency word:  心 136
# High frequency word:  たる 133
# High frequency word:  気 132
# High frequency word:  ま 131
# High frequency word:  ので 131
# High frequency word:  ご 131
# High frequency word:  それから 130
# High frequency word:  こう 129
# High frequency word:  君 125
# High frequency word:  とき 122
# High frequency word:  く 121
# High frequency word:  見る 120
# High frequency word:  目 120
# High frequency word:  ］ 119
# High frequency word:  年 118
# High frequency word:  たい 118
# High frequency word:  あたし 118
# High frequency word:  少し 115
# High frequency word:  今 114
# High frequency word:  わたし 114
# High frequency word:  さちよ 114
# High frequency word:  出し 113
# High frequency word:  外 113
# High frequency word:  話 113
# High frequency word:  まだ 111
# High frequency word:  うち 110
# High frequency word:  間 109
# High frequency word:  様 108
# High frequency word:  位 107
# High frequency word:  又 107
# High frequency word:  め 107
# High frequency word:  余 107
# High frequency word:  けれども 106
# High frequency word:  方 105
# High frequency word:  - 102
# High frequency word:  いま 101
# High frequency word:  僕 101
# High frequency word:  かけ 100
# High frequency word:  所 100
# High frequency word:  眼 100
# High frequency word:  ら 99
# High frequency word:  保吉 98
# High frequency word:  一つ 98
# High frequency word:  後 98
# High frequency word:  誰 98
# High frequency word:  え 98
# High frequency word:  我 97
# High frequency word:  居る 97
# High frequency word:  まま 96
# High frequency word:  下 96
# High frequency word:  云う 96
# High frequency word:  ため 95
# High frequency word:  だっ 95
# High frequency word:  そんな 95
# High frequency word:  くれ 94
# High frequency word:  あつ 94
# High frequency word:  お前 94
# High frequency word:  者 93
# High frequency word:  れる 93
# High frequency word:  犬 91
# High frequency word:  ひとり 91
# High frequency word:  口 90
# High frequency word:  ほう 90
# High frequency word:  す 89
# High frequency word:  ぢ 88
# High frequency word:  言う 88
# High frequency word:  どこ 88
# High frequency word:  出来 88
# High frequency word:  彼女 88
# High frequency word:  来る 87
# High frequency word:  的 87
# High frequency word:  六 86
# High frequency word:  らしい 86
# High frequency word:  でしょ 85
# High frequency word:  店 84
# High frequency word:  ほど 84
# High frequency word:  なかつ 84
# High frequency word:  ところ 84
# High frequency word:  あれ 83
# High frequency word:  なけれ 83
# High frequency word:  って 83
# High frequency word:  ここ 82
# High frequency word:  でし 82
# High frequency word:  下さい 82
# High frequency word:  居り 81
# High frequency word:  として 80
# High frequency word:  ただ 80
# High frequency word:  無い 80
# High frequency word:  くらい 80
# High frequency word:  つた 78
# High frequency word:  すぐ 77
# High frequency word:  じ 77
# High frequency word:  聞い 77
# High frequency word:  右 77
# High frequency word:  知れ 76
# High frequency word:  ふと 76
# High frequency word:  感じ 76
# High frequency word:  こ 76
# High frequency word:  行 76
# High frequency word:  メロス 76
# High frequency word:  そこ 75
# High frequency word:  言い 75
# High frequency word:  だろ 75
# High frequency word:  思う 75
# High frequency word:  身 75
# High frequency word:  四 75
# High frequency word:  思ひ 74
# High frequency word:  け 74
# High frequency word:  思ふ 74
# High frequency word:  まい 74
# High frequency word:  同じ 73
# High frequency word:  知ら 73
# High frequency word:  見え 72
# High frequency word:  なん 72
# High frequency word:  言葉 72
# High frequency word:  父 72
# High frequency word:  行っ 71
# High frequency word:  のに 70
# High frequency word:  忠利 70
# High frequency word:  信子 69
# High frequency word:  國 69
# High frequency word:  度 68
# High frequency word:  光 68
# High frequency word:  ゝ 68
# High frequency word:  やはり 67
# High frequency word:  そうして 67
# High frequency word:  だって 67
# High frequency word:  大 67
# High frequency word:  七 67
# High frequency word:  是 67
# High frequency word:  主人 66
# High frequency word:  物 66
# High frequency word:  つけ 66
# High frequency word:  第 66
# High frequency word:  馬 66
# High frequency word:  來 66
# High frequency word:  にて 66
# High frequency word:  ち 65
# High frequency word:  程 65
# High frequency word:  ！ 64
# High frequency word:  百 64
# High frequency word:  思い 64
# High frequency word:  ども 64
# High frequency word:  かも 63
# High frequency word:  （ 63
# High frequency word:  こんな 63
# High frequency word:  子 63
# High frequency word:  知っ 63
# High frequency word:  しまっ 63
# High frequency word:  わたくし 63
# High frequency word:  人間 63
# High frequency word:  ぞ 62
# High frequency word:  しよ 62
# High frequency word:  夜 62
# High frequency word:  ねえ 62
# High frequency word:  ほ 61
# High frequency word:  なつ 61
# High frequency word:  母 61
# High frequency word:  さえ 61
# High frequency word:  仁 61
# High frequency word:  之 61
# High frequency word:  田島 61
# High frequency word:  とも 60
# High frequency word:  げ 60
# High frequency word:  酒 60
# High frequency word:  ど 60
# High frequency word:  考え 60
# High frequency word:  部屋 60
# High frequency word:  郎 60
# High frequency word:  すると 59
# High frequency word:  頃 59
# High frequency word:  利 59
# High frequency word:  立っ 58
# High frequency word:  頭 58
# High frequency word:  殉死 58
# High frequency word:  衛門 58
# High frequency word:  或 57
# High frequency word:  本 57
# High frequency word:  よく 57
# High frequency word:  語 57
# High frequency word:  のみ 56
# High frequency word:  あら 56
# High frequency word:  内 56
# High frequency word:  風 56
# High frequency word:  どうも 55
# High frequency word:  言 55
# High frequency word:  歩い 55
# High frequency word:  色 54
# High frequency word:  妻 54
# High frequency word:  婆さん 54
# High frequency word:  いっ 54
# High frequency word:  姫君 54
# High frequency word:  持っ 54
# High frequency word:  斯 54
# High frequency word:  ） 53
# High frequency word:  八 53
# High frequency word:  自身 52
# High frequency word:  わけ 52
# High frequency word:  ああ 52
# High frequency word:  々 52
# High frequency word:  ろ 52
# High frequency word:  皆 52
# High frequency word:  やっ 52
# High frequency word:  勿論 51
# High frequency word:  死ん 51
# High frequency word:  そこで 51
# High frequency word:  行く 51
# High frequency word:  申し 51
# High frequency word:  とか 51
# High frequency word:  侍 51
# High frequency word:  髪長 51
# High frequency word:  彦 51
# High frequency word:  姫 51
# High frequency word:  其の 51
# High frequency word:  此 51
# High frequency word:  笑っ 50
# High frequency word:  ほか 49
# High frequency word:  かう 49
# High frequency word:  石 49
# High frequency word:  やら 49
# High frequency word:  通り 48
# High frequency word:  朝 48
# High frequency word:  あと 48
# High frequency word:  姿 48
# High frequency word:  いけ 48
# High frequency word:  でき 48
# High frequency word:  氏 48
# High frequency word:  数枝 48
# High frequency word:  つい 47
# High frequency word:  居 47
# High frequency word:  はいっ 47
# High frequency word:  べき 47
# High frequency word:  青年 47
# High frequency word:  半 47
# High frequency word:  得 47
# High frequency word:  まあ 46
# High frequency word:  足 46
# High frequency word:  先 46
# High frequency word:  用 46
# High frequency word:  うし 46
# High frequency word:  字 46
# High frequency word:  阿部 46
# High frequency word:  忘れ 45
# High frequency word:  帰っ 45
# High frequency word:  それでも 45
# High frequency word:  もと 45
# High frequency word:  早く 45
# High frequency word:  どんな 45
# High frequency word:  弟 45
# High frequency word:  1 45
# High frequency word:  ちょっと 45
# High frequency word:  キヌ子 45
# High frequency word:  大谷 45
# High frequency word:  だい 44
# High frequency word:  彼等 44
# High frequency word:  とうとう 44
# High frequency word:  っ 44
# High frequency word:  常子 44
# High frequency word:  悪い 43
# High frequency word:  耳 43
# High frequency word:  音 43
# High frequency word:  空 43
# High frequency word:  胸 43
# High frequency word:  ばか 43
# High frequency word:  しょ 43
# High frequency word:  涙 43
# High frequency word:  有 43
# High frequency word:  道 43
# High frequency word:  山 43
# High frequency word:  窓 42
# High frequency word:  違 42
# High frequency word:  やつ 42
# High frequency word:  ふも 42
# High frequency word:  子供 42
# High frequency word:  神 42
# High frequency word:  命 42
# High frequency word:  聞え 42
# High frequency word:  行き 42
# High frequency word:  婆 42
# High frequency word:  あろ 42
# High frequency word:  少女 42
# High frequency word:  思わ 42
# High frequency word:  わから 42
# High frequency word:  ほとんど 42
# High frequency word:  られる 42
# High frequency word:  様子 42
# High frequency word:  数馬 42
# High frequency word:  乙彦 42
# High frequency word:  つき 41
# High frequency word:  かみ 41
# High frequency word:  火 41
# High frequency word:  水準 41
# High frequency word:  歳 41
# High frequency word:  金 41
# High frequency word:  はじめ 41
# High frequency word:  相手 40
# High frequency word:  名 40
# High frequency word:  書い 40
# High frequency word:  昔 40
# High frequency word:  今日 40
# High frequency word:  伊織 40
# High frequency word:  なんて 40
# High frequency word:  例 39
# High frequency word:  微笑 39
# High frequency word:  円 39
# High frequency word:  しか 39
# High frequency word:  遠藤 39
# High frequency word:  ましょ 39
# High frequency word:  妹 39
# High frequency word:  たく 39
# High frequency word:  生活 38
# High frequency word:  ゆ 38
# High frequency word:  唯 38
# High frequency word:  信じ 38

# %%
def stopword_bydic(text):
    """
    辞書によるストップワードの除去
    """
    # 読み込むストップワード辞書の指定。
    with open('./origin_stopwords.txt') as f:
        data = f.read()
        stopwords = data.split('\n')
    lines = []
    for line in text:
        words = []
        for word in line:
            if word not in stopwords:
                words.append(word)    
        lines.append(words)
    return lines

# %%
sum_lines = len(stopword_bydic(cleaned_data))
sum_words = []
for line in stopword_bydic(cleaned_data):
    for word in line:
        if word not in sum_words:
            sum_words.append(word)
print('sum_lines: ', sum_lines)
print('sum_words: ', len(sum_words))
with open('origin_words.txt', 'w') as f:
    f.write('\n'.join(sum_words))
cleaned_data = []
for author, data in authors.items():
    data = stopword_bydic(data)
    for line in data:
        #if len(line) > 2:
        cleaned_data.append(author+','+' '.join(line))
# Out:
# sum_lines:  8876
# sum_words:  13489

# %%
# 作成したコーパスの保存
with open('./dataset/corpus.csv', 'w') as f:
    f.write(''.join(cleaned_data))
